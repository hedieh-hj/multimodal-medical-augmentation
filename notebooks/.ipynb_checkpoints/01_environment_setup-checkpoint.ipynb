# %%
# Import basic modules
import os
import sys

# Add src folder to Python path
sys.path.append("../src")

# %%
# Install necessary packages if needed
# !pip install --quiet pandas pillow torch torchvision matplotlib scikit-learn

# Import packages
# Allow DLLs to load properly on Windows
os.environ["CUDA_MODULE_LOADING"] = "LAZY"
import pandas as pd
from PIL import Image
import torch

print("All packages imported successfully")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 9
#       7 import pandas as pd
#       8 from PIL import Image
# ----> 9 import torch
#      11 print("All packages imported successfully")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:280
#     276                     raise err
#     278         kernel32.SetErrorMode(prev_error_mode)
# --> 280     _load_dll_libraries()
#     281     del _load_dll_libraries
#     284 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     285     # Libraries can either be in
#     286     # path/nvidia/lib_folder/lib or
#     287     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     288     # path/lib_folder/lib
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:263, in _load_dll_libraries()
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio
# Out:
# Found existing installation: torch 2.10.0+cpu
# Uninstalling torch-2.10.0+cpu:
#   Successfully uninstalled torch-2.10.0+cpu
# Found existing installation: torchvision 0.25.0+cpu
# Uninstalling torchvision-0.25.0+cpu:
#   Successfully uninstalled torchvision-0.25.0+cpu
# Found existing installation: torchaudio 2.10.0+cpu
# Uninstalling torchaudio-2.10.0+cpu:
#   Successfully uninstalled torchaudio-2.10.0+cpu

# %%
pip install torch==2.0.1+cpu torchvision==0.15.2+cpu torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cpu

# %%
    import torch
print(torch.__version__)
print("Torch imported successfully (CPU-only)")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import torch
#       2 print(torch.__version__)
#       3 print("Torch imported successfully (CPU-only)")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:280
#     276                     raise err
#     278         kernel32.SetErrorMode(prev_error_mode)
# --> 280     _load_dll_libraries()
#     281     del _load_dll_libraries
#     284 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     285     # Libraries can either be in
#     286     # path/nvidia/lib_folder/lib or
#     287     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     288     # path/lib_folder/lib
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\__init__.py:263, in _load_dll_libraries()
#     259     err = ctypes.WinError(last_error)
# ...
